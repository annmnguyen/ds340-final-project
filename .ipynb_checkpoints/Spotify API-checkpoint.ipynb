# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

CLIENT_ID = 'd20b032e9f9a4252a0e907d3edc7f615'
CLIENT_SECRET = '295697b34c7c470c8f3de7e013379aae'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(CLIENT_ID, CLIENT_SECRET))

# %%
import pandas as pd
df = pd.read_csv("dataset.csv")
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
id = df["track_id"].iloc[0:50]
ids = id.tolist()

# %%
tracks = spotify.tracks(ids)
# Out:
# huh
# huh

# %%
tracks["tracks"][3]["preview_url"]
# Out:
# 'https://p.scdn.co/mp3-preview/1e7bfa0d6eed45d57c658acabf4cee389e6b44a6?cid=d20b032e9f9a4252a0e907d3edc7f615'

# %%
import librosa
y, sr = librosa.load('mp3/478669e1ce29f94cccc7a4a0f80cc18a149a5b91.mp3')
mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr)

# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mel_spectrogram_db, sr=sr, cmap='viridis')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel Spectrogram')
plt.show()


type(mel_spectrogram_db)
sys.getsizeof(mel_spectrogram_db)
# Out:
# 655488

# %%
spec = df[['track_id']].copy()
spec["url"] = ''
spec
# Out:
#                       track_id url
# 0       5SuOikwiRyPMVoIQDJUgSV
# 1       4qPNDBW1i3p13qLCt0Ki3A
# 2       1iJBSr7s7jYXzM8EGcbK5b
# 3       6lfxq3CG4xtTiEg7opyCyx
# 4       5vjLSffimiIP26QG5WcN2K
# ...                        ...  ..
# 113995  2C3TZjDRiAzdyViavDJ217
# 113996  1hIz5L4IB9hN3WRYPOCGPw
# 113997  6x8ZfSoqDjuNa5SVP5QjvX
# 113998  2e6sXL2bYv4bSz6VTdnfLs
# 113999  2hETkH7cOfqmz3LqZDHZf5
#
# [114000 rows x 2 columns]

# %%
k = 350
id = df["track_id"].iloc[k:k+50]
ids = id.tolist()

# %%
tracks = spotify.tracks(ids)

# %%
import time
s = time.time()
n = len(spec)
iter = k
for i in tracks["tracks"]:
    url = i["preview_url"]
    spec.loc[iter, "url"] = url
    iter += 1
print(time.time()-s)
# Out:
# 0.0024902820587158203

# %%
sum = 0
for i in range(len(spec)):
    if(spec.loc[i, "url"] == None):
        sum += 1
print(sum)
# Out:
# 118
